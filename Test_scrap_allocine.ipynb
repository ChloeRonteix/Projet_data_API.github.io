# %%
import pandas as pd
import bs4
import urllib.request
import csv
import re
import requests

# %%
#robots rejetés par allocine.fr
from urllib.request import urlopen

with urlopen("http://www.allocine.fr/robots.txt") as stream:
    print(stream.read().decode("utf-8"))
# Out:
# User-Agent:*
# Disallow: /recherche/
# Disallow: /salle/recherche/
# Disallow: /monallocine/
# Disallow: /blogvision/
# Disallow: /communaute/membre/reportabuseforum_gen_nofil=*
# Disallow: /*?*iframe*
# Disallow: /ws/AcVisiondata.ashx?*
# Disallow: /ws/AcVisiondataV4.ashx?*
# Disallow: /ws/ProfilLightGetModerationLink.ashx?*
# Disallow: /ws/geocoding.ashx
# Disallow: /ws_v7/geocoding.ashx
# Disallow: /ws/WinnerListHandler.ashx
# Disallow: /ws/PostRollTrailer.ashx?*
# Disallow: /ws/partnerproxy.ashx?*
# Disallow: /ws_v7/Disqus.asmx/
# Disallow: /ws_v7/get_complete_photos_list.ashx?*
# Disallow: /120157152/
# Disallow: /doubleclick/
# Disallow: /_/
# Disallow: /_video/partner/
# Disallow: /communaute/forum/
#
# User-Agent: seekbot
# Disallow: /
#
# User-Agent: Exabot
# Disallow: /
#
# User-agent: Slurp
# Disallow: /
#
# User-agent: Cliqzbot
# Disallow: /

# %%
#nom de mon user_agent
requests.utils.default_user_agent()
# Out:
# 'python-requests/2.22.0'

# %%
#requêtage de l'url et aspiration du code source des pages web visées
import requests

#for i in pages:
    #response = requests.get(i)
response = requests.get('http://www.allocine.fr/films/?page=2')

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="fr">\n<head>\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <meta charset="UTF-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no">\n    <meta name="robots" content="index,follow,max-snippet:-1" />\n        <title>Les films les plus populaires - AlloCiné</title>\n    <meta name="keywords" content="" />\n    <meta name="Googlebot" content="noarchive" />\n    <meta name="distribution" content="global" />\n    <meta name="author" content="AlloCine" />\n    <meta name="country" content="France" />\n    <meta name="geo.position" content="48.87078;2.30447" />\n    <meta name="geo.country" content="FR" />\n        <meta name="ICBM" content="48.87078;2.30447" />\n    <meta name="theme-color" content="#FECC00" />\n    <meta name="description" content="Découvrez tous les films les plus populaires sur AlloCiné, comme :  Police, Tenet, Enorme" />\n 
# ...

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')
#print(soup)
em_box = soup.find_all("div", {"class":"entity-card-list"})
print(len(em_box))
# Out:
# 15

# %% [markdown]
# # Les titres

# %%
#titre des films
titleUnique_box = soup.find("a", {"class":"meta-title-link"})
titleUnique_box.get_text()
# Out:
# 'Police'

# %%
titles_box = soup.find_all("a", {"class":"meta-title-link"})
titles = []
ids = []
for title in titles_box:
    titles.append(title.text)
    url = title['href']
    start = url.index('=')+1
    end = url.index('.')
    ids.append(url[start:end])
print(titles)
print(ids)
# Out:
# ['Police', 'Tenet', 'Enorme', 'Effacer l’historique', 'Larguées', 'Petit Pays', 'Les Nouveaux mutants', 'La Daronne', "Dans un jardin qu'on dirait éternel", 'Black Panther 2', 'Aline', 'Antebellum', 'La Proie', 'Boutchou', 'Ema']
# ['267302', '251315', '258205', '275608', '255741', '269704', '237864', '268644', '272059', '263242', '261294', '275832', '175909', '272061', '266744']

# %% [markdown]
# # ID Films

# %%
ids_box = soup.find_all("a", {"class":"meta-title-link"})
ids = []
for id in ids_box:
    ids.append(title.text)
print(titles)
# Out:
# ['Police', 'Tenet', 'Enorme', 'Effacer l’historique', 'Larguées', 'Petit Pays', 'Les Nouveaux mutants', 'La Daronne', "Dans un jardin qu'on dirait éternel", 'Black Panther 2', 'Aline', 'Antebellum', 'La Proie', 'Boutchou', 'Ema']

# %% [markdown]
# # Date de sortie

# %%
#date de sortie
years_box = soup.find_all("span", {"class":"date"})
years = []
for year in years_box:
    years.append(year.text)
print(years)
# Out:
# ['2 septembre 2020', '26 août 2020', '2 septembre 2020', '26 août 2020', '18 avril 2018', '28 août 2020', '26 août 2020', '9 septembre 2020', '26 août 2020', '4 mai 2022', '18 novembre 2020', '9 septembre 2020', '13 avril 2011', '23 septembre 2020', '2 septembre 2020']

# %% [markdown]
# # Genres

# %%
meta_body_info = soup.find_all("div", {"class":"meta-body-item meta-body-info"})
list_spans = []
for i in meta_body_info:
    spans = i.find_all('span')
    #print(spans)
    list_spans.append(spans)

spans_genre = []
for span in list_spans:
    del span[0:3]
    spans_genre.append(span)
    #print(span)
#print(spans_genre)
#print('--------------------------------------------')
#print(spans_genre[0][0].text)

tableau_genres = []
for film in spans_genre:
    genres = []
    for genre in film:
        genres.append(genre.text)
    tableau_genres.append(genres)
print(tableau_genres)
# Out:
# [['Thriller', 'Drame'], ['Action', 'Science fiction'], ['Comédie'], ['Comédie', 'Drame'], ['Comédie'], ['Drame'], ['Epouvante-horreur', 'Thriller', 'Fantastique'], ['Policier', 'Comédie'], ['Comédie dramatique'], ['Aventure', 'Fantastique'], ['Comédie dramatique'], ['Thriller', 'Epouvante-horreur'], ['Action', 'Thriller', 'Policier'], [], ['Drame', 'Thriller']]

# %%
#genre
#parent = soup.find('li', {'class': 'text'})
#children = parent.findChildren("a" , recursive=False)
#for child in children:
    #print child
meta_body_info = soup.find("div", {"class":"meta-body-item meta-body-info"})
print(type(meta_body_info))
genres = meta_body_info.find_all("span")
print(genres)
del genres[0:3]
list_genre = []
for genre in genres:
    list_genre.append(genre.text)
print(list_genre)
# Out:
# <class 'bs4.element.Tag'>
# [<span class="date">2 septembre 2020</span>, <span class="spacer">/</span>, <span class="spacer">/</span>, <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIzLw==">Thriller</span>, <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>]
# ['Thriller', 'Drame']

# %%
act = soup.find_all("div", {"class":"meta-body-actor"})
act
# Out:
# [<div class="meta-body-item meta-body-actor">
#  <span class="light">Avec</span>
#  <a href="/personne/fichepersonne_gen_cpersonne=87127.html">Omar Sy</a>,
#
#
#                                                                                      <a href="/personne/fichepersonne_gen_cpersonne=97635.html">Virginie Efira</a>,
#
#
#                                                                                      <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0xNjcyNTQuaHRtbA==">Grégory Gadebois</span>
#  </div>,
#  <div class="meta-body-item meta-body-actor">
#  <span class="light">Avec</span>
#  <a href="/personne/fichepersonne_gen_cpersonne=418466.html">John David Washington</a>,
#
#
#                                                                                      <a href="/personne/fichepersonne_gen_cpersonne=97604.html">Robert Pattinson</a>,
#
#
# ...

# %% [markdown]
# # Realisateurs

# %%
real = soup.find_all("a", {"class":"blue-link"})
realisateurs = []
for realisateur in real:
    realisateurs.append(realisateur.text)
print(realisateurs)
# Out:
# ['Anne Fontaine', 'Christopher Nolan', 'Sophie Letourneur', 'Gustave Kervern', 'Eloïse Lang', 'Eric Barbier', 'Josh Boone', 'Jean-Paul Salomé', 'Tatsushi Ōmori', 'Ryan Coogler', 'Valérie Lemercier', 'Gerard Bush', 'Eric Valette', 'Adrien Piquet-Gauthier', 'Pablo Larraín']

# %% [markdown]
# # Acteurs

# %%
act = soup.find_all("div", {"class":"meta-body-actor"})
print(act)
acteurs = []
acteur_clean =[]
for acteur in act:
    acteurs = acteur.find_all(["a","span"], class_=(lambda x: x != 'light'))
    for acteur in acteurs:
        acteur_film = acteur.text
        print(acteur_film)
    #acteurs.append(acteur.text)
#for i in acteurs:
    #acteur_clean.append((" ".join(i.split()).replace('Avec', '')))
#print(acteur_clean)
# Out:
# [<div class="meta-body-item meta-body-actor">
# <span class="light">Avec</span>
# <a href="/personne/fichepersonne_gen_cpersonne=418466.html">John David Washington</a>,
#
#
#                                                                                     <a href="/personne/fichepersonne_gen_cpersonne=97604.html">Robert Pattinson</a>,
#
#
#                                                                                     <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT01MjE5ODcuaHRtbA==">Elizabeth Debicki</span>
# </div>, <div class="meta-body-item meta-body-actor">
# <span class="light">Avec</span>
# <a href="/personne/fichepersonne_gen_cpersonne=87127.html">Omar Sy</a>,
#
#
#                                                                                     <a href="/personne/fichepersonne_gen_cpersonne=97635.html">Virginie Efira</a>,
#
#
# ...

# %% [markdown]
# # Synopsis

# %%
synops = soup.find_all("div", {"class":"content-txt"})
synopsis=[]
synopsis_clean=[]
for i in synops:
    synopsis.append(i.text)
for i in synopsis:
    synopsis_clean.append((" ".join(i.split())))
print(synopsis)
# Out:
# ["\n                      Muni d'un seul mot – Tenet – et décidé à se battre pour sauver le monde, notre protagoniste sillonne l'univers crépusculaire de l'espionnage international. Sa mission le projettera dans une dimension qui dépasse le temps.\xa0Pourtant, il ne s'agit pas d'un voyage dans le temps, mais d'un renversement temporel…\n        \n            ", '\n                      Virginie, Erik et Aristide, trois flics parisiens, se voient obligés d’accepter une mission inhabituelle : reconduire un étranger à la frontière.\n        \n            ', '\n                      Ça lui prend d’un coup à 40 ans : Frédéric veut un bébé, Claire elle n’en a jamais voulu et ils étaient bien d’accord là-dessus. Il commet l’impardonnable et lui fait un enfant dans le dos. Claire se transforme en baleine et Frédéric\xa0devient\xa0gnangnan.\n        \n            ', "\n                      Dans un lotissement en province, trois voisins sont en prise avec les nouvelles technologies et les rés
# ...

# %% [markdown]
# # Note Presse

# %% [markdown]
# Attention!!!! Comment gérer les notes inexistantes!!!

# %%
evaluation = soup.find_all('div', {'class':'rating-holder'})
#print(evaluation)
notes_presse = []
for rating in evaluation:
    note = rating.find('span', {'class': 'stareval-note'})
    notes_presse.append(float((note.text).replace(',', '.')))
print(notes_presse)
# Out:
# [3.3, 3.7, 3.6, 4.0, 3.2, 3.7, 2.2, 3.9, 3.0, 3.4]

# %%
em_box = soup.find_all("div", {"class":"entity-card-list"})
print(len(em_box))

for film in em_box:
    evaluation = film.find_all('div', {'class':'rating-holder'})
    note_presse = 0
    note_spec = 0
    if len(evaluation) != 0:
        for rating in evaluation:
            notes = rating.find_all('span', {'class': 'stareval-note'})
            note_presse += float((notes[0].text).replace(',', '.'))
            note_spec += float((notes[1].text).replace(',', '.'))
    print(note_presse, note_spec)
# Out:
# 15
# 3.4 3.2
# 3.9 4.1
# 3.8 3.1
# 3.6 3.8
# 3.3 3.5
# 0 0
# 0 0
# 0 0
# 3.6 3.5
# 2.0 2.5
# 2.9 3.3
# 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-357c7e846583> in <module>
#      10             notes = rating.find_all('span', {'class': 'stareval-note'})
#      11             note_presse += float((notes[0].text).replace(',', '.'))
# ---> 12             note_spec += float((notes[1].text).replace(',', '.'))
#      13     print(note_presse, note_spec)
#      14
#
# ValueError: could not convert string to float: '--'

# %% [markdown]
# # Note Spectateurs

# %% [markdown]
# Attention!!!! Comment gérer les notes inexistantes!!!

# %%
evaluation = soup.find_all('div', {'class':'rating-holder'})
#print(evaluation)
evas = []
for eva in evaluation:
    rat = eva.find_all('span')
    evas.append(rat)
print(evas)
list_notes = []
for note in evas:
    del note[0:3]
    del note[-1]
    list_notes.append(note)
#print(list_notes)

notes_spec = []
for i in list_notes:
    for note in i:
        notes_spec.append(float((note.text).replace(',', '.')))
#print(notes_spec)
# Out:
# [[<span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTMxNS9jcml0aXF1ZXMvcHJlc3NlLw== rating-title"> Presse </span>, <span class="stareval-note">3,7</span>, <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1MTMxNS9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv rating-title"> Spectateurs </span>, <span class="stareval-note">3,9</span>, <span class="stareval-note no-rating">--</span>], [<span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI2NzMwMi9jcml0aXF1ZXMvcHJlc3NlLw== rating-title"> Presse </span>, <span class="stareval-note">3,3</span>, <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI2NzMwMi9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv rating-title"> Spectateurs </span>, <span class="stareval-note">2,0</span>, <span class="stareval-note no-rating">--</span>], [<span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1ODIwNS9jcml0aXF1ZXMvcHJlc3NlLw== rating-title"> Presse </span>, <span class="stareval-note">3,6</span>, <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTI1ODIwNS9jcml0aXF1ZXMvc3BlY3RhdGV1cnMv rating-title"> Spectateurs </span>, <span class="stareval-not
# ...

# %% [markdown]
# # DataFrame

# %%
#d = {'Titres': titles, 'Sorties': years, 'List_Genres': tableau_genres, 'Realisateurs' : realisateurs, 'Acteurs': acteur_clean, 'Synopsis': synopsis_clean}
#df = pd.DataFrame(d)
#df

# %%
#df['liststring'] = [','.join(map(str, l)) for l in df['lists']]
df['Genres'] = [', '.join(map(str, l)) for l in df['List_Genres']]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-cead33a9f528> in <module>
#       1 #df['liststring'] = [','.join(map(str, l)) for l in df['lists']]
# ----> 2 df['Genres'] = [', '.join(map(str, l)) for l in df['List_Genres']]
#       3 df
#
# NameError: name 'df' is not defined

# %%
data_film = df.drop(columns=['List_Genres'])
data_film

# %%
data_film['Synopsis'].iloc[0]

# %% [markdown]
# # Film par film

# %%
soup = bs4.BeautifulSoup(response.text, 'html.parser')
#print(soup)
em_box = soup.find_all("div", {"class":"entity-card-list"})
print(len(em_box))
# Out:
# 15

# %%
print(em_box[0])
# Out:
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <a class="thumbnail-container thumbnail-link" href="/video/player_gen_cmedia=19585567&amp;cfilm=267302.html" title="Bande-annonce Police">
# <img alt="Bande-annonce Police" class="thumbnail-img" height="288" src="http://fr.web.img2.acsta.net/c_215_290/pictures/20/08/18/08/26/5562385.jpg" width="216"/>
# <span class="ico-play ico-play-yellow">
# <span class="ico-play-inner"></span>
# <i class="ico-play-arrow">
# <i class="arrow"></i>
# </i>
# </span>
# </a>
# </figure>
# <div class="meta">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/film/fichefilm_gen_cfilm=267302.html">Police</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">2 septembre 2020</span>
# <span class="spacer">/</span>
#
#
#                                             1h 39min
#
#                                             <span class="spacer">/</span>
# ...

# %%
# Titre
title_url = em_box[1].find("a", {"class":"meta-title-link"})
title = title_url.text
print(title)
#Id du film
url = title_url['href']
start = url.index('=')+1
end = url.index('.')
id_film = int(url[start:end])
print(id_film)
#Acteurs
actors = em_box[1].find('div', {'class':'meta-body-actor'})
acteurs
acteur_clean = []
acteur_clean.append((" ".join(actors.text.split()).replace('Avec ', '')))
print(acteur_clean)
#Realisateur
real = em_box[1].find("a", {"class":"blue-link"}).text
print(real)
#date
date = em_box[1].find('span', {'class':'date'}).text
print(date)
#Genres
meta_body_info = em_box[1].find("div", {"class":"meta-body-info"})
genres = meta_body_info.find_all("a", {"href":"/films/genre-^"})
list_genre = []
for genre in genres:
    list_genre.append(genre.text)
print(list_genre)
# Out:
# Police
# 267302
# ['Omar Sy, Virginie Efira, Grégory Gadebois']
# Anne Fontaine
# 2 septembre 2020
# []
# []

# %%
meta_body_info = em_box[1].find("div", {"class":"meta-body-info"})
genres_film = meta_body_info.find_all("span", class_=lambda x: x != 'date' and x != 'spacer')
genres =[]
for genre in genres_film:
    genres.append(genre.text)
print(meta_body_info)
print(genres)
# Out:
# <div class="meta-body-item meta-body-info">
# <span class="date">2 septembre 2020</span>
# <span class="spacer">/</span>
#
#
#                                             1h 39min
#
#                                             <span class="spacer">/</span>
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIzLw==">Thriller</span>,
#
#                                                 <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw==">Drame</span>
# </div>
# ['Thriller', 'Drame']

# %%
df2 = pd.DataFrame(columns=('titre', 'id', 'acteurs', 'realisateur', 'date de sortie', 'genres', 'synopsis'))
df2
# Out:
# Empty DataFrame
# Columns: [titre, id, acteurs, realisateur, date de sortie, genres, synopsis]
# Index: []

# %%
for film in em_box:
    # Titre
    title_url = film.find("a", {"class":"meta-title-link"})
    title = title_url.text
    #print(title)
    #Id du film
    url = title_url['href']
    start = url.index('=')+1
    end = url.index('.')
    id_film = int(url[start:end])
    #print(id_film)
    #Acteurs
    actors = film.find('div', {'class':'meta-body-actor'})
    acteur_clean = []
    acteur_clean.append((" ".join(actors.text.split()).replace('Avec ', '')))
    #print(acteur_clean)
    #Realisateur
    real = film.find("a", {"class":"blue-link"}).text
    #print(real)
    #date
    date = film.find('span', {'class':'date'}).text
    #print(date)
    #Genres
    meta_body_info = film.find("div", {"class":"meta-body-info"})
    genres = meta_body_info.find_all("span")
    del genres[0:3]
    list_genre = []
    for genre in genres:
        list_genre.append(genre.text)
    #synopsis
    synops = film.find_all("div", {"class":"content-txt"})
    synopsis=[]
    synopsis_clean=[]
    for i in synops:
        synopsis.append(i.text)
    for i in synopsis:
        synopsis_clean.append((" ".join(i.split())))
    #print(synopsis_clean)
    df2 = df2.append({'titre':title, 'id':id_film, 'acteurs':acteur_clean, 'realisateur':real, 'date de sortie':date, 'genres':list_genre, 'synopsis':synopsis_clean}, ignore_index=True)
df2
    #print(list_genre)
    #print('---------------------------------------------------------------------')
# Out:
#                                   titre      id  \
# 0                                Police  267302
# 1                                 Tenet  251315
# 2                                Enorme  258205
# 3                  Effacer l’historique  275608
# 4                              Larguées  255741
# 5                            Petit Pays  269704
# 6                  Les Nouveaux mutants  237864
# 7                            La Daronne  268644
# 8   Dans un jardin qu'on dirait éternel  272059
# 9                       Black Panther 2  263242
# 10                                Aline  261294
# 11                           Antebellum  275832
# 12                             La Proie  175909
# 13                             Boutchou  272061
# 14                                  Ema  266744
#
#                                               acteurs             realisateur  \
# 0         [Omar Sy, Virginie Efira, Grégory Gadebois]           Anne Fontaine
# ...

# %%
df2['Genres'] = [', '.join(map(str, l)) for l in df2['genres']]
df2['Synopsis'] = [', '.join(map(str, l)) for l in df2['synopsis']]
df2['Acteurs'] = [', '.join(map(str, l)) for l in df2['acteurs']]
data = df2.drop(columns=['acteurs','synopsis','genres'])

data
# Out:
#                                   titre      id             realisateur  \
# 0                                Police  267302           Anne Fontaine
# 1                                 Tenet  251315       Christopher Nolan
# 2                                Enorme  258205       Sophie Letourneur
# 3                  Effacer l’historique  275608         Gustave Kervern
# 4                              Larguées  255741             Eloïse Lang
# 5                            Petit Pays  269704            Eric Barbier
# 6                  Les Nouveaux mutants  237864              Josh Boone
# 7                            La Daronne  268644        Jean-Paul Salomé
# 8   Dans un jardin qu'on dirait éternel  272059          Tatsushi Ōmori
# 9                       Black Panther 2  263242            Ryan Coogler
# 10                                Aline  261294       Valérie Lemercier
# 11                           Antebellum  275832             Gerard Bush
# ...

# %%
synops = em_box[1].find("div", {"class":"content-txt"})
synops.text.strip()
# Out:
# 'Mauvaise journée pour Rachel : en retard pour conduire son fils à l’école, elle se retrouve coincée au feu derrière une voiture qui ne redémarre pas. Perdant patience, elle klaxonne et passe devant. Quelques mètres plus loin, le même pick up s’arrête à son niveau. Son conducteur la somme de s’excuser, mais elle refuse. Furieux, il commence à la suivre... La journée de Rachel se transforme en véritable cauchemar.'

# %%
from dateutil.parser import parse
datetime = parse(em_box[1].find('span', {'class':'date'}).text)
datetime
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-25-7fd0d00f99af> in <module>
#       1 from dateutil.parser import parse
# ----> 2 datetime = parse(em_box[1].find('span', {'class':'date'}).text)
#       3 datetime
#
# ~/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/anaconda3/lib/python3.7/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     647
#     648         if res is None:
# --> 649             raise ParserError("Unknown string format: %s", timestr)
#     650
#     651         if len(res) == 0:
#
# ParserError: Unknown string format: 19 août 2020

# %%
from datetime import datetime
date_sortie = em_box[1].find('span', {'class':'date'}).text
print(date_sortie)
date = datetime.strptime(date_sortie, '%d %B %Y')
date
# Out:
# 19 août 2020
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-393df26aac99> in <module>
#       2 date_sortie = em_box[1].find('span', {'class':'date'}).text
#       3 print(date_sortie)
# ----> 4 date = datetime.strptime(date_sortie, '%d %B %Y')
#       5 date
#
# ~/anaconda3/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
# ...
